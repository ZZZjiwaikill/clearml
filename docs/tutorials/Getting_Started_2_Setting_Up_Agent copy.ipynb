# %% [markdown]
# <div align="center">
#
#   <a href="https://clear.ml" target="_blank">
#     <img width="512", src="https://github.com/allegroai/clearml/raw/master/docs/clearml-logo.svg"></a>
#
#
# <br>
#
# <h1>Notebook 2: Remote Agent</h1>
#
# <br>
#
# Hi there! This is the second notebook in the ClearML getting started notebook series, meant to teach you the ropes. ClearML has a lot of modules that you can use, so in this notebook, we'll contiue the progress that we made in <a href="https://colab.research.google.com/github/allegroai/clearml/blob/master/docs/tutorials/Getting_Started_1_Experiment_Management.ipynb" target="_blank">our first notebook</a>: <a href="https://app.clear.ml/workers-and-queues/workers" target="_blank">Remote Agents.</a>
#
# You can find out more details about the other ClearML modules and the technical specifics of each in <a href="https://clear.ml/docs" target="_blank">our documentation.</a>
#
# <table>
# <tbody>
#   <tr>
#     <td>Step 1: Experiment Management</td>
#     <td><a target="_blank" href="https://colab.research.google.com/github/allegroai/clearml/blob/master/docs/tutorials/Getting_Started_1_Experiment_Management.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a></td>
#   </tr>
#   <tr>
#     <td><b>Step 2: Remote Agent</b></td>
#     <td><a target="_blank" href="https://colab.research.google.com/github/allegroai/clearml/blob/master/docs/tutorials/Getting_Started_2_Setting_Up_Agent.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a></td>
#   </tr>
#   <tr>
#     <td>Step 3: Remote Task Execution</td>
#     <td><a target="_blank" href="https://colab.research.google.com/github/allegroai/clearml/blob/master/docs/tutorials/Getting_Started_3_Remote_Execution.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a></td>
#   </tr>
# </tbody>
# </table>
#
# </div>

# %% [markdown]
# # 📦 Setup
#
# ClearML allows you to schedule and run your experiments on any number of clustered remote machines. In order to coordinate this, you will have to turn these remote machines into ClearML agents.
#
# A ClearML agent is any remote machine that is running the ClearML agent daemon. This agent can then listen to one or more queues and pull tasks to execute. Multiple agents can work together as a cluster to deal with large amounts of incoming tasks.
#
# To keep things simple, let's turn this very notebook into a ClearML agent! (I told you "any" remote machine would work, did I not 😉 That includes this colab machine)

# %% [markdown]
# ## 🔹 Install the ClearML agent package

# %%
# %pip install --upgrade clearml
import clearml
clearml.browser_login()
# Out:
# Requirement already satisfied: clearml in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (2.1.9)
# Requirement already satisfied: attrs>=18.0 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml) (26.1.0)
# Requirement already satisfied: furl>=2.0.0 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml) (2.1.4)
# Requirement already satisfied: jsonschema>=2.6.0 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml) (4.25.1)
# Requirement already satisfied: numpy>=1.26.4 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml) (2.4.6)
# Requirement already satisfied: pathlib2>=2.3.0 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml) (2.3.7.post1)
# Requirement already satisfied: Pillow>=10.3.0 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml) (12.2.0)
# Requirement already satisfied: psutil>=3.4.2 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml) (7.0.0)
# Requirement already satisfied: pyparsing>=2.0.3 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml) (2.9.0.post0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.4.0 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml) (2.8.0)
# Requirement already satisfied: PyYAML>=3.12 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml) (6.0.3)
# Requirement already satisfied: referencing<0.40 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml) (0.37.0)
# Requirement already satisfied: requests>=2.32.0 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml) (2.32.5)
# Requirement already satisfied: six>=1.16.0 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml) (1.17.0)
# Requirement already satisfied: urllib3>=1.21.1 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml) (2.7.0)
# Requirement already satisfied: rpds-py>=0.7.0 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from referencing<0.40->clearml) (0.28.0)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from furl>=2.0.0->clearml) (1.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from jsonschema>=2.6.0->clearml) (2025.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from requests>=2.32.0->clearml) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from requests>=2.32.0->clearml) (3.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from requests>=2.32.0->clearml) (2026.6.17)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade clearml-agent
# Out:
# Requirement already satisfied: clearml-agent in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (3.0.3)
# Requirement already satisfied: psutil<7.3,>=3.4.2 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml-agent) (7.0.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml-agent) (2.7.0)
# Requirement already satisfied: virtualenv<21,>=16 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml-agent) (20.39.1)
# Requirement already satisfied: requests<2.33,>=2.20.0 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml-agent) (2.32.5)
# Requirement already satisfied: setuptools<82.0.0 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from clearml-agent) (81.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from requests<2.33,>=2.20.0->clearml-agent) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from requests<2.33,>=2.20.0->clearml-agent) (3.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from requests<2.33,>=2.20.0->clearml-agent) (2026.6.17)
# Requirement already satisfied: distlib<1,>=0.3.7 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from virtualenv<21,>=16->clearml-agent) (0.4.3)
# Requirement already satisfied: filelock<4,>=3.24.2 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from virtualenv<21,>=16->clearml-agent) (3.29.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages (from virtualenv<21,>=16->clearml-agent) (4.9.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 🧠 Start the agent
#
# This section is actually pretty simple! To setup this notebook machine as a ClearML agent, run the following command.
#
# (We're adding `--foreground` so you can see your tasks being executed here later!)

# %%
# !clearml-agent daemon --queue "default" --foreground
# Out:
# /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages/clearml_agent/external/requirements_parser/requirement.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import Requirement as Req  # noqa
# /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages/urllib3/connection.py:928: FutureWarning: 'ssl_version' option is deprecated and will be removed in urllib3 v3.0. Instead use 'ssl_minimum_version'
#   context = create_urllib3_context(
# INFO: clearml-agent-bootstrap was not detected.
#       We recommend installing it to significantly reduce agent job start-up time.
#       To install, run: clearml-agent install-bootstrap
#       See: https://github.com/clearml/clearml-agent-bootstrap
# Current configuration (clearml_agent v3.0.3, location: /home/zhouyunqi/clearml.conf):
# ----------------------
# sdk.storage.cache.default_base_dir = ~/.clearml/cache
# sdk.storage.cache.size.min_free_bytes = 10GB
# sdk.storage.cache.disk_space_file_size_strategy.enabled = false
# sdk.storage.cache.disk_space_file_size_strategy.size.max_used_bytes = -1
# sdk.storage.cache.disk_space_file_size_strategy.size.min_free_bytes = 10GB
# sdk.storage.cache.disk_space_file_size_strategy.zero_file_size_check = false
# sdk.storage.cache.disk_space_file_size_strategy.file_entry_lookup_size = 0
# sdk.storage.direct_access.0.url = file://*
# sdk.storage.block_pickled_artifacts = false
# sdk.metrics.file_history_size = 100
# sdk.metrics.matplotlib_untitled_history_size = 100
# sdk.metrics.images.format = JPEG
# sdk.metrics.images.quality = 87
# sdk.metrics.images.subsampling = 0
# sdk.metrics.tensorboard_single_series_per_graph = false
# sdk.network.metrics.file_upload_threads = 4
# sdk.network.metrics.file_upload_starvation_warning_sec = 120
# sdk.network.iteration.max_retries_on_server_error = 5
# sdk.network.iteration.retry_backoff_factor_sec = 10
# sdk.network.file_upload_retries = 3
# sdk.aws.s3.key =
# sdk.aws.s3.secret = ****
# sdk.aws.s3.region =
# sdk.aws.s3.use_credentials_chain = false
# sdk.aws.boto3.pool_connections = 512
# sdk.aws.boto3.max_multipart_concurrency = 16
# sdk.aws.boto3.multipart_threshold = 8388608
# sdk.aws.boto3.multipart_chunksize = 8388608
# sdk.log.null_log_propagate = false
# sdk.log.task_log_buffer_capacity = 66
# sdk.log.disable_urllib3_info = true
# sdk.development.task_reuse_time_window_in_hours = 72.0
# sdk.development.vcs_repo_detect_async = true
# sdk.development.store_uncommitted_code_diff = true
# sdk.development.support_stopping = true
# sdk.development.default_output_uri =
# sdk.development.force_analyze_entire_repo = false
# sdk.development.suppress_update_message = false
# sdk.development.detect_with_pip_freeze = false
# sdk.development.worker.report_period_sec = 2
# sdk.development.worker.ping_period_sec = 30
# sdk.development.worker.log_stdout = true
# sdk.development.worker.report_global_mem_used = false
# sdk.development.worker.report_event_flush_threshold = 100
# sdk.development.worker.console_cr_flush_period = 10
# sdk.development.store_dataviews_on_creation = true
# sdk.development.default_shell_binary = /bin/bash
# sdk.development.artifacts.auto_pickle = true
# sdk.apply_environment = false
# sdk.apply_files = false
# api.version = 1.5
# api.verify_certificate = true
# api.default_version = 1.5
# api.http.max_req_size = 15728640
# api.http.retries.total = 240
# api.http.retries.connect = 240
# api.http.retries.read = 240
# api.http.retries.redirect = 240
# api.http.retries.status = 240
# api.http.retries.backoff_factor = 1.0
# api.http.retries.backoff_max = 120.0
# api.http.wait_on_maintenance_forever = true
# api.http.pool_maxsize = 512
# api.http.pool_connections = 512
# api.auth.token_expiration_threshold_sec = ****
# api.api_server = https://api.clear.ml
# api.web_server = https://app.clear.ml/
# api.files_server = https://files.clear.ml
# api.credentials.access_key = 4TM21VIZSBZHPIC5SYHKB54N7KGLI7
# api.credentials.secret_key = ****
# api.host = https://api.clear.ml
# agent.worker_id =
# agent.worker_name = icesn93
# agent.force_git_ssh_protocol = false
# agent.git_fetch_args.0 = --all
# agent.git_fetch_args.1 = --tags
# agent.git_fetch_args.2 = --recurse-submodules
# agent.python_binary =
# agent.package_manager.type = pip
# agent.package_manager.pip_version.0 = <20.2 ; python_version < '3.10'
# agent.package_manager.pip_version.1 = <22.3 ; python_version >\= '3.10' and python_version <\= '3.11'
# agent.package_manager.pip_version.2 = >\=23,<26 ; python_version >\= '3.12'
# agent.package_manager.uv_sync_locked_if_lock_file = true
# agent.package_manager.system_site_packages = false
# agent.package_manager.force_upgrade = false
# agent.package_manager.pip_legacy_resolver.0 = >\=20.3,<24.3
# agent.package_manager.conda_channels.0 = pytorch
# agent.package_manager.conda_channels.1 = conda-forge
# agent.package_manager.conda_channels.2 = nvidia
# agent.package_manager.conda_channels.3 = defaults
# agent.package_manager.priority_optional_packages.0 = pygobject
# agent.package_manager.torch_nightly = false
# agent.package_manager.poetry_files_from_repo_working_dir = false
# agent.package_manager.uv_files_from_repo_working_dir = false
# agent.venvs_dir = /home/zhouyunqi/.clearml/venvs-builds
# agent.venvs_cache.max_entries = 10
# agent.venvs_cache.free_space_threshold_gb = 2.0
# agent.venvs_cache.path = ~/.clearml/venvs-cache
# agent.vcs_cache.enabled = true
# agent.vcs_cache.path = /home/zhouyunqi/.clearml/vcs-cache
# agent.pip_download_cache.enabled = true
# agent.pip_download_cache.path = /home/zhouyunqi/.clearml/pip-download-cache
# agent.translate_ssh = true
# agent.translate_ssl_replacement_scheme = https
# agent.reload_config = false
# agent.docker_pip_cache = /home/zhouyunqi/.clearml/pip-cache
# agent.docker_apt_cache = /home/zhouyunqi/.clearml/apt-cache
# agent.forbidden_docker_args.0 = entrypoint
# agent.bootstrap.use_bootstrap = true
# agent.bootstrap.check_for_latest = false
# agent.bootstrap.check_for_latest_timeout = 5
# agent.bootstrap.host_bootstrap_dir = ~/.clearml.bootstrap
# agent.bootstrap.host_bootstrap_cache_dir = ~/.clearml.bootstrap.cache
# agent.bootstrap.skip_git_installation = true
# agent.bootstrap.always_use_static_git = false
# agent.bootstrap.always_install_ca_cert = true
# agent.docker_force_pull = false
# agent.default_docker.image = nvidia/cuda:12.6.3-cudnn-runtime-ubuntu20.04
# agent.default_docker.update_back_task = true
# agent.default_docker.match_rules.0.image = python:3.6-bullseye
# agent.default_docker.match_rules.0.arguments = --ipc\=host
# agent.default_docker.match_rules.0.update_back_task = true
# agent.default_docker.match_rules.0.match.script.binary = python3.6$
# agent.default_docker.match_rules.1.image = python:3.7-bullseye
# agent.default_docker.match_rules.1.arguments = --ipc\=host
# agent.default_docker.match_rules.1.update_back_task = true
# agent.default_docker.match_rules.1.match.script.binary = python3.7$
# agent.default_docker.match_rules.2.image = python:3.8-bullseye
# agent.default_docker.match_rules.2.arguments = --ipc\=host
# agent.default_docker.match_rules.2.match.script.binary = python3.8$
# agent.default_docker.match_rules.3.image = python:3.9-bullseye
# agent.default_docker.match_rules.3.arguments = --ipc\=host
# agent.default_docker.match_rules.3.match.script.binary = python3.9$
# agent.default_docker.match_rules.4.image = python:3.10-bullseye
# agent.default_docker.match_rules.4.arguments = --ipc\=host
# agent.default_docker.match_rules.4.match.script.binary = python3.10$
# agent.default_docker.match_rules.5.image = python:3.11-bullseye
# agent.default_docker.match_rules.5.arguments = --ipc\=host
# agent.default_docker.match_rules.5.match.script.binary = python3.11$
# agent.default_docker.match_rules.6.image = python:3.12-bullseye
# agent.default_docker.match_rules.6.arguments = --ipc\=host
# agent.default_docker.match_rules.6.match.script.binary = python3.12$
# agent.default_docker.match_rules.7.image = python:3.13-bullseye
# agent.default_docker.match_rules.7.arguments = --ipc\=host
# agent.default_docker.match_rules.7.match.script.binary = python3.13$
# agent.enable_task_env = false
# agent.sanitize_config_printout = ****
# agent.hide_docker_command_env_vars.enabled = true
# agent.hide_docker_command_env_vars.parse_embedded_urls = true
# agent.abort_callback_max_timeout = 1800
# agent.docker_internal_mounts.bootstrap_folder = /.clearml.bootstrap
# agent.docker_internal_mounts.bootstrap_cache = /.clearml.bootstrap.cache
# agent.docker_internal_mounts.sdk_cache = /clearml_agent_cache
# agent.docker_internal_mounts.apt_cache = /var/cache/apt/archives
# agent.docker_internal_mounts.ssh_folder = ~/.ssh
# agent.docker_internal_mounts.ssh_ro_folder = /.ssh
# agent.docker_internal_mounts.pip_cache = /root/.cache/pip
# agent.docker_internal_mounts.poetry_cache = /root/.cache/pypoetry
# agent.docker_internal_mounts.vcs_cache = /root/.clearml/vcs-cache
# agent.docker_internal_mounts.venvs_cache = /root/.clearml/venvs-cache
# agent.docker_internal_mounts.venv_build = ~/.clearml/venvs-builds
# agent.docker_internal_mounts.pip_download = /root/.clearml/pip-download-cache
# agent.apply_environment = true
# agent.docker_apply_environment_from_vault = true
# agent.apply_files = true
# agent.custom_build_script =
# agent.disable_task_docker_override = false
# agent.default_python = 3.13
# agent.cuda_version = 132
# agent.cudnn_version = 0
#
# Worker "icesn93:0" - Listening to queues:
# +----------------------------------+---------+-------+
# | id                               | name    | tags  |
# +----------------------------------+---------+-------+
# | 3b0af7445ac445678838e7b47c7f05bd | default |       |
# +----------------------------------+---------+-------+
#
# task a7d6c079e4964af6820fafd99d3909e2 pulled from 3b0af7445ac445678838e7b47c7f05bd by worker icesn93:0
# Running task 'a7d6c079e4964af6820fafd99d3909e2'
# Storing stdout and stderr log to '/tmp/.clearml_agent_out._ywv2uci.txt', '/tmp/.clearml_agent_out._ywv2uci.txt'
# /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages/clearml_agent/external/requirements_parser/requirement.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import Requirement as Req  # noqa
# Using custom configuration file from env var: /tmp/.clearml_agent.lw5g_ffv.cfg
# /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages/urllib3/connection.py:928: FutureWarning: 'ssl_version' option is deprecated and will be removed in urllib3 v3.0. Instead use 'ssl_minimum_version'
#   context = create_urllib3_context(
# Current configuration (clearml_agent v3.0.3, location: /tmp/.clearml_agent.lw5g_ffv.cfg):
# ----------------------
# sdk.storage.cache.default_base_dir = ~/.clearml/cache
# sdk.storage.cache.size.min_free_bytes = 10GB
# sdk.storage.cache.disk_space_file_size_strategy.enabled = false
# sdk.storage.cache.disk_space_file_size_strategy.size.max_used_bytes = -1
# sdk.storage.cache.disk_space_file_size_strategy.size.min_free_bytes = 10GB
# sdk.storage.cache.disk_space_file_size_strategy.zero_file_size_check = false
# sdk.storage.cache.disk_space_file_size_strategy.file_entry_lookup_size = 0
# sdk.storage.direct_access.0.url = file://*
# sdk.storage.block_pickled_artifacts = false
# sdk.metrics.file_history_size = 100
# sdk.metrics.matplotlib_untitled_history_size = 100
# sdk.metrics.images.format = JPEG
# sdk.metrics.images.quality = 87
# sdk.metrics.images.subsampling = 0
# sdk.metrics.tensorboard_single_series_per_graph = false
# sdk.network.metrics.file_upload_threads = 4
# sdk.network.metrics.file_upload_starvation_warning_sec = 120
# sdk.network.iteration.max_retries_on_server_error = 5
# sdk.network.iteration.retry_backoff_factor_sec = 10
# sdk.network.file_upload_retries = 3
# sdk.aws.s3.key =
# sdk.aws.s3.secret = ****
# sdk.aws.s3.region =
# sdk.aws.s3.use_credentials_chain = false
# sdk.aws.boto3.pool_connections = 512
# sdk.aws.boto3.max_multipart_concurrency = 16
# sdk.aws.boto3.multipart_threshold = 8388608
# sdk.aws.boto3.multipart_chunksize = 8388608
# sdk.log.null_log_propagate = false
# sdk.log.task_log_buffer_capacity = 66
# sdk.log.disable_urllib3_info = true
# sdk.development.task_reuse_time_window_in_hours = 72.0
# sdk.development.vcs_repo_detect_async = true
# sdk.development.store_uncommitted_code_diff = true
# sdk.development.support_stopping = true
# sdk.development.default_output_uri =
# sdk.development.force_analyze_entire_repo = false
# sdk.development.suppress_update_message = false
# sdk.development.detect_with_pip_freeze = false
# sdk.development.worker.report_period_sec = 2
# sdk.development.worker.ping_period_sec = 30
# sdk.development.worker.log_stdout = true
# sdk.development.worker.report_global_mem_used = false
# sdk.development.worker.report_event_flush_threshold = 100
# sdk.development.worker.console_cr_flush_period = 10
# sdk.development.store_dataviews_on_creation = true
# sdk.development.default_shell_binary = /bin/bash
# sdk.development.artifacts.auto_pickle = true
# sdk.apply_environment = false
# sdk.apply_files = false
# api.version = 1.5
# api.verify_certificate = true
# api.default_version = 1.5
# api.http.max_req_size = 15728640
# api.http.retries.total = 240
# api.http.retries.connect = 240
# api.http.retries.read = 240
# api.http.retries.redirect = 240
# api.http.retries.status = 240
# api.http.retries.backoff_factor = 1.0
# api.http.retries.backoff_max = 120.0
# api.http.wait_on_maintenance_forever = true
# api.http.pool_maxsize = 512
# api.http.pool_connections = 512
# api.auth.token_expiration_threshold_sec = ****
# api.api_server = https://api.clear.ml
# api.web_server = https://app.clear.ml/
# api.files_server = https://files.clear.ml
# api.credentials.access_key = 4TM21VIZSBZHPIC5SYHKB54N7KGLI7
# api.credentials.secret_key = ****
# api.host = https://api.clear.ml
# agent.worker_id = icesn93:0
# agent.worker_name = icesn93
# agent.force_git_ssh_protocol = false
# agent.git_fetch_args.0 = --all
# agent.git_fetch_args.1 = --tags
# agent.git_fetch_args.2 = --recurse-submodules
# agent.python_binary =
# agent.package_manager.type = pip
# agent.package_manager.pip_version.0 = <20.2 ; python_version < '3.10'
# agent.package_manager.pip_version.1 = <22.3 ; python_version >\= '3.10' and python_version <\= '3.11'
# agent.package_manager.pip_version.2 = >\=23,<26 ; python_version >\= '3.12'
# agent.package_manager.uv_sync_locked_if_lock_file = true
# agent.package_manager.system_site_packages = false
# agent.package_manager.force_upgrade = false
# agent.package_manager.pip_legacy_resolver.0 = >\=20.3,<24.3
# agent.package_manager.conda_channels.0 = pytorch
# agent.package_manager.conda_channels.1 = conda-forge
# agent.package_manager.conda_channels.2 = nvidia
# agent.package_manager.conda_channels.3 = defaults
# agent.package_manager.priority_optional_packages.0 = pygobject
# agent.package_manager.torch_nightly = false
# agent.package_manager.poetry_files_from_repo_working_dir = false
# agent.package_manager.uv_files_from_repo_working_dir = false
# agent.venvs_dir = /home/zhouyunqi/.clearml/venvs-builds
# agent.venvs_cache.max_entries = 10
# agent.venvs_cache.free_space_threshold_gb = 2.0
# agent.venvs_cache.path = ~/.clearml/venvs-cache
# agent.vcs_cache.enabled = true
# agent.vcs_cache.path = /home/zhouyunqi/.clearml/vcs-cache
# agent.pip_download_cache.enabled = true
# agent.pip_download_cache.path = /home/zhouyunqi/.clearml/pip-download-cache
# agent.translate_ssh = true
# agent.translate_ssl_replacement_scheme = https
# agent.reload_config = false
# agent.docker_pip_cache = /home/zhouyunqi/.clearml/pip-cache
# agent.docker_apt_cache = /home/zhouyunqi/.clearml/apt-cache
# agent.forbidden_docker_args.0 = entrypoint
# agent.bootstrap.use_bootstrap = true
# agent.bootstrap.check_for_latest = false
# agent.bootstrap.check_for_latest_timeout = 5
# agent.bootstrap.host_bootstrap_dir = ~/.clearml.bootstrap
# agent.bootstrap.host_bootstrap_cache_dir = ~/.clearml.bootstrap.cache
# agent.bootstrap.skip_git_installation = true
# agent.bootstrap.always_use_static_git = false
# agent.bootstrap.always_install_ca_cert = true
# agent.docker_force_pull = false
# agent.default_docker.image = nvidia/cuda:12.6.3-cudnn-runtime-ubuntu20.04
# agent.default_docker.update_back_task = true
# agent.default_docker.match_rules.0.image = python:3.6-bullseye
# agent.default_docker.match_rules.0.arguments = --ipc\=host
# agent.default_docker.match_rules.0.update_back_task = true
# agent.default_docker.match_rules.0.match.script.binary = python3.6$
# agent.default_docker.match_rules.1.image = python:3.7-bullseye
# agent.default_docker.match_rules.1.arguments = --ipc\=host
# agent.default_docker.match_rules.1.update_back_task = true
# agent.default_docker.match_rules.1.match.script.binary = python3.7$
# agent.default_docker.match_rules.2.image = python:3.8-bullseye
# agent.default_docker.match_rules.2.arguments = --ipc\=host
# agent.default_docker.match_rules.2.match.script.binary = python3.8$
# agent.default_docker.match_rules.3.image = python:3.9-bullseye
# agent.default_docker.match_rules.3.arguments = --ipc\=host
# agent.default_docker.match_rules.3.match.script.binary = python3.9$
# agent.default_docker.match_rules.4.image = python:3.10-bullseye
# agent.default_docker.match_rules.4.arguments = --ipc\=host
# agent.default_docker.match_rules.4.match.script.binary = python3.10$
# agent.default_docker.match_rules.5.image = python:3.11-bullseye
# agent.default_docker.match_rules.5.arguments = --ipc\=host
# agent.default_docker.match_rules.5.match.script.binary = python3.11$
# agent.default_docker.match_rules.6.image = python:3.12-bullseye
# agent.default_docker.match_rules.6.arguments = --ipc\=host
# agent.default_docker.match_rules.6.match.script.binary = python3.12$
# agent.default_docker.match_rules.7.image = python:3.13-bullseye
# agent.default_docker.match_rules.7.arguments = --ipc\=host
# agent.default_docker.match_rules.7.match.script.binary = python3.13$
# agent.enable_task_env = false
# agent.sanitize_config_printout = ****
# agent.hide_docker_command_env_vars.enabled = true
# agent.hide_docker_command_env_vars.parse_embedded_urls = true
# agent.abort_callback_max_timeout = 1800
# agent.docker_internal_mounts.bootstrap_folder = /.clearml.bootstrap
# agent.docker_internal_mounts.bootstrap_cache = /.clearml.bootstrap.cache
# agent.docker_internal_mounts.sdk_cache = /clearml_agent_cache
# agent.docker_internal_mounts.apt_cache = /var/cache/apt/archives
# agent.docker_internal_mounts.ssh_folder = ~/.ssh
# agent.docker_internal_mounts.ssh_ro_folder = /.ssh
# agent.docker_internal_mounts.pip_cache = /root/.cache/pip
# agent.docker_internal_mounts.poetry_cache = /root/.cache/pypoetry
# agent.docker_internal_mounts.vcs_cache = /root/.clearml/vcs-cache
# agent.docker_internal_mounts.venvs_cache = /root/.clearml/venvs-cache
# agent.docker_internal_mounts.venv_build = ~/.clearml/venvs-builds
# agent.docker_internal_mounts.pip_download = /root/.clearml/pip-download-cache
# agent.apply_environment = true
# agent.docker_apply_environment_from_vault = true
# agent.apply_files = true
# agent.custom_build_script =
# agent.disable_task_docker_override = false
# agent.default_python = 3.13
# agent.cuda_version = 132
# agent.cudnn_version = 0
#
# Executing task id [a7d6c079e4964af6820fafd99d3909e2]:
# repository = https://github.com/allegroai/clearml
# branch = master
# version_num =
# tag =
# docker_cmd = python:3.9-bullseye
# entry_point = hyper_parameter_optimizer.py
# working_dir = examples/optimization/hyper-parameter-optimization
#
# Python executable with version '3.9' requested by the Task, not found in path, using '/home/zhouyunqi/miniconda3/envs/env2/bin/python3' (v3.13.11) instead
# INFO: acquiring lock [timeout=30.0s] for cache folder: /home/zhouyunqi/.clearml/venvs-cache
#
#
# INFO: acquiring [timeout=300s] lock for repo cache folder
# cloning: https://github.com/allegroai/clearml
# fatal: unable to access 'https://github.com/allegroai/clearml/': Error in the HTTP2 framing layer
#
# Repository cloning failed: Command '['clone', 'https://github.com/allegroai/clearml', '/home/zhouyunqi/.clearml/vcs-cache/clearml.7015b45737b028c74fd56b2f91aeabda/clearml', '--recursive', '--quiet']' returned non-zero exit status 128.
# Task failed: stopping task (4) exception
#
# Leaving process id 833513
# /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages/urllib3/connection.py:928: FutureWarning: 'ssl_version' option is deprecated and will be removed in urllib3 v3.0. Instead use 'ssl_minimum_version'
#   context = create_urllib3_context(
#
# clearml_agent: ERROR: Failed cloning repository.
# 1) Make sure you pushed the requested commit:
# (repository='https://github.com/allegroai/clearml', branch='master', commit_id='', tag='', docker_cmd='python:3.9-bullseye', entry_point='hyper_parameter_optimizer.py', working_dir='examples/optimization/hyper-parameter-optimization')
# 2) Check if remote-worker has valid credentials [see worker configuration file]
#
#
# Leaving process id 833513
# DONE: Running task 'a7d6c079e4964af6820fafd99d3909e2' (user aborted)
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 3b0af7445ac445678838e7b47c7f05bd
# No tasks in Queues, sleeping for 5.0 seconds
# task 108aa81a4217427d84877d80d216fbe2 pulled from 3b0af7445ac445678838e7b47c7f05bd by worker icesn93:0
# Running task '108aa81a4217427d84877d80d216fbe2'
# Storing stdout and stderr log to '/tmp/.clearml_agent_out.84le1orz.txt', '/tmp/.clearml_agent_out.84le1orz.txt'
# /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages/clearml_agent/external/requirements_parser/requirement.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import Requirement as Req  # noqa
# Using custom configuration file from env var: /tmp/.clearml_agent.lw5g_ffv.cfg
# /home/zhouyunqi/miniconda3/envs/env2/lib/python3.13/site-packages/urllib3/connection.py:928: FutureWarning: 'ssl_version' option is deprecated and will be removed in urllib3 v3.0. Instead use 'ssl_minimum_version'
#   context = create_urllib3_context(
# Current configuration (clearml_agent v3.0.3, location: /tmp/.clearml_agent.lw5g_ffv.cfg):
# ----------------------
# sdk.storage.cache.default_base_dir = ~/.clearml/cache
# sdk.storage.cache.size.min_free_bytes = 10GB
# sdk.storage.cache.disk_space_file_size_strategy.enabled = false
# sdk.storage.cache.disk_space_file_size_strategy.size.max_used_bytes = -1
# sdk.storage.cache.disk_space_file_size_strategy.size.min_free_bytes = 10GB
# sdk.storage.cache.disk_space_file_size_strategy.zero_file_size_check = false
# sdk.storage.cache.disk_space_file_size_strategy.file_entry_lookup_size = 0
# sdk.storage.direct_access.0.url = file://*
# sdk.storage.block_pickled_artifacts = false
# sdk.metrics.file_history_size = 100
# sdk.metrics.matplotlib_untitled_history_size = 100
# sdk.metrics.images.format = JPEG
# sdk.metrics.images.quality = 87
# sdk.metrics.images.subsampling = 0
# sdk.metrics.tensorboard_single_series_per_graph = false
# sdk.network.metrics.file_upload_threads = 4
# sdk.network.metrics.file_upload_starvation_warning_sec = 120
# sdk.network.iteration.max_retries_on_server_error = 5
# sdk.network.iteration.retry_backoff_factor_sec = 10
# sdk.network.file_upload_retries = 3
# sdk.aws.s3.key =
# sdk.aws.s3.secret = ****
# sdk.aws.s3.region =
# sdk.aws.s3.use_credentials_chain = false
# sdk.aws.boto3.pool_connections = 512
# sdk.aws.boto3.max_multipart_concurrency = 16
# sdk.aws.boto3.multipart_threshold = 8388608
# sdk.aws.boto3.multipart_chunksize = 8388608
# sdk.log.null_log_propagate = false
# sdk.log.task_log_buffer_capacity = 66
# sdk.log.disable_urllib3_info = true
# sdk.development.task_reuse_time_window_in_hours = 72.0
# sdk.development.vcs_repo_detect_async = true
# sdk.development.store_uncommitted_code_diff = true
# sdk.development.support_stopping = true
# sdk.development.default_output_uri =
# sdk.development.force_analyze_entire_repo = false
# sdk.development.suppress_update_message = false
# sdk.development.detect_with_pip_freeze = false
# sdk.development.worker.report_period_sec = 2
# sdk.development.worker.ping_period_sec = 30
# sdk.development.worker.log_stdout = true
# sdk.development.worker.report_global_mem_used = false
# sdk.development.worker.report_event_flush_threshold = 100
# sdk.development.worker.console_cr_flush_period = 10
# sdk.development.store_dataviews_on_creation = true
# sdk.development.default_shell_binary = /bin/bash
# sdk.development.artifacts.auto_pickle = true
# sdk.apply_environment = false
# sdk.apply_files = false
# api.version = 1.5
# api.verify_certificate = true
# api.default_version = 1.5
# api.http.max_req_size = 15728640
# api.http.retries.total = 240
# api.http.retries.connect = 240
# api.http.retries.read = 240
# api.http.retries.redirect = 240
# api.http.retries.status = 240
# api.http.retries.backoff_factor = 1.0
# api.http.retries.backoff_max = 120.0
# api.http.wait_on_maintenance_forever = true
# api.http.pool_maxsize = 512
# api.http.pool_connections = 512
# api.auth.token_expiration_threshold_sec = ****
# api.api_server = https://api.clear.ml
# api.web_server = https://app.clear.ml/
# api.files_server = https://files.clear.ml
# api.credentials.access_key = 4TM21VIZSBZHPIC5SYHKB54N7KGLI7
# api.credentials.secret_key = ****
# api.host = https://api.clear.ml
# agent.worker_id = icesn93:0
# agent.worker_name = icesn93
# agent.force_git_ssh_protocol = false
# agent.git_fetch_args.0 = --all
# agent.git_fetch_args.1 = --tags
# agent.git_fetch_args.2 = --recurse-submodules
# agent.python_binary =
# agent.package_manager.type = pip
# agent.package_manager.pip_version.0 = <20.2 ; python_version < '3.10'
# agent.package_manager.pip_version.1 = <22.3 ; python_version >\= '3.10' and python_version <\= '3.11'
# agent.package_manager.pip_version.2 = >\=23,<26 ; python_version >\= '3.12'
# agent.package_manager.uv_sync_locked_if_lock_file = true
# agent.package_manager.system_site_packages = false
# agent.package_manager.force_upgrade = false
# agent.package_manager.pip_legacy_resolver.0 = >\=20.3,<24.3
# agent.package_manager.conda_channels.0 = pytorch
# agent.package_manager.conda_channels.1 = conda-forge
# agent.package_manager.conda_channels.2 = nvidia
# agent.package_manager.conda_channels.3 = defaults
# agent.package_manager.priority_optional_packages.0 = pygobject
# agent.package_manager.torch_nightly = false
# agent.package_manager.poetry_files_from_repo_working_dir = false
# agent.package_manager.uv_files_from_repo_working_dir = false
# agent.venvs_dir = /home/zhouyunqi/.clearml/venvs-builds
# agent.venvs_cache.max_entries = 10
# agent.venvs_cache.free_space_threshold_gb = 2.0
# agent.venvs_cache.path = ~/.clearml/venvs-cache
# agent.vcs_cache.enabled = true
# agent.vcs_cache.path = /home/zhouyunqi/.clearml/vcs-cache
# agent.pip_download_cache.enabled = true
# agent.pip_download_cache.path = /home/zhouyunqi/.clearml/pip-download-cache
# agent.translate_ssh = true
# agent.translate_ssl_replacement_scheme = https
# agent.reload_config = false
# agent.docker_pip_cache = /home/zhouyunqi/.clearml/pip-cache
# agent.docker_apt_cache = /home/zhouyunqi/.clearml/apt-cache
# agent.forbidden_docker_args.0 = entrypoint
# agent.bootstrap.use_bootstrap = true
# agent.bootstrap.check_for_latest = false
# agent.bootstrap.check_for_latest_timeout = 5
# agent.bootstrap.host_bootstrap_dir = ~/.clearml.bootstrap
# agent.bootstrap.host_bootstrap_cache_dir = ~/.clearml.bootstrap.cache
# agent.bootstrap.skip_git_installation = true
# agent.bootstrap.always_use_static_git = false
# agent.bootstrap.always_install_ca_cert = true
# agent.docker_force_pull = false
# agent.default_docker.image = nvidia/cuda:12.6.3-cudnn-runtime-ubuntu20.04
# agent.default_docker.update_back_task = true
# agent.default_docker.match_rules.0.image = python:3.6-bullseye
# agent.default_docker.match_rules.0.arguments = --ipc\=host
# agent.default_docker.match_rules.0.update_back_task = true
# agent.default_docker.match_rules.0.match.script.binary = python3.6$
# agent.default_docker.match_rules.1.image = python:3.7-bullseye
# agent.default_docker.match_rules.1.arguments = --ipc\=host
# agent.default_docker.match_rules.1.update_back_task = true
# agent.default_docker.match_rules.1.match.script.binary = python3.7$
# agent.default_docker.match_rules.2.image = python:3.8-bullseye
# agent.default_docker.match_rules.2.arguments = --ipc\=host
# agent.default_docker.match_rules.2.match.script.binary = python3.8$
# agent.default_docker.match_rules.3.image = python:3.9-bullseye
# agent.default_docker.match_rules.3.arguments = --ipc\=host
# agent.default_docker.match_rules.3.match.script.binary = python3.9$
# agent.default_docker.match_rules.4.image = python:3.10-bullseye
# agent.default_docker.match_rules.4.arguments = --ipc\=host
# agent.default_docker.match_rules.4.match.script.binary = python3.10$
# agent.default_docker.match_rules.5.image = python:3.11-bullseye
# agent.default_docker.match_rules.5.arguments = --ipc\=host
# agent.default_docker.match_rules.5.match.script.binary = python3.11$
# agent.default_docker.match_rules.6.image = python:3.12-bullseye
# agent.default_docker.match_rules.6.arguments = --ipc\=host
# agent.default_docker.match_rules.6.match.script.binary = python3.12$
# agent.default_docker.match_rules.7.image = python:3.13-bullseye
# agent.default_docker.match_rules.7.arguments = --ipc\=host
# agent.default_docker.match_rules.7.match.script.binary = python3.13$
# agent.enable_task_env = false
# agent.sanitize_config_printout = ****
# agent.hide_docker_command_env_vars.enabled = true
# agent.hide_docker_command_env_vars.parse_embedded_urls = true
# agent.abort_callback_max_timeout = 1800
# agent.docker_internal_mounts.bootstrap_folder = /.clearml.bootstrap
# agent.docker_internal_mounts.bootstrap_cache = /.clearml.bootstrap.cache
# agent.docker_internal_mounts.sdk_cache = /clearml_agent_cache
# agent.docker_internal_mounts.apt_cache = /var/cache/apt/archives
# agent.docker_internal_mounts.ssh_folder = ~/.ssh
# agent.docker_internal_mounts.ssh_ro_folder = /.ssh
# agent.docker_internal_mounts.pip_cache = /root/.cache/pip
# agent.docker_internal_mounts.poetry_cache = /root/.cache/pypoetry
# agent.docker_internal_mounts.vcs_cache = /root/.clearml/vcs-cache
# agent.docker_internal_mounts.venvs_cache = /root/.clearml/venvs-cache
# agent.docker_internal_mounts.venv_build = ~/.clearml/venvs-builds
# agent.docker_internal_mounts.pip_download = /root/.clearml/pip-download-cache
# agent.apply_environment = true
# agent.docker_apply_environment_from_vault = true
# agent.apply_files = true
# agent.custom_build_script =
# agent.disable_task_docker_override = false
# agent.default_python = 3.13
# agent.cuda_version = 132
# agent.cudnn_version = 0
#
# Executing task id [108aa81a4217427d84877d80d216fbe2]:
# repository =
# branch =
# version_num =
# tag =
# docker_cmd =
# entry_point = ipykernel_launcher.py
# working_dir = .
#
# INFO: acquiring lock [timeout=30.0s] for cache folder: /home/zhouyunqi/.clearml/venvs-cache
#
#
#
#
# Ignoring pip: markers 'python_version < "3.10"' don't match your environment
# Ignoring pip: markers 'python_version >= "3.10" and python_version <= "3.11"' don't match your environment
# Requirement already satisfied: pip<26,>=23 in /home/zhouyunqi/.clearml/venvs-builds/3.13/lib/python3.13/site-packages (25.3)
# Skipping 1 pre-installed packages:
# [clearml==2.1.9]
# Remaining 1 additional packages to install
# Collecting ipykernel==7.2.0 (from -r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading ipykernel-7.2.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting comm>=0.1.1 (from ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting debugpy>=1.6.5 (from ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading debugpy-1.8.21-cp313-cp313-manylinux_2_34_x86_64.whl.metadata (1.4 kB)
# Collecting ipython>=7.23.1 (from ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading ipython-9.15.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting jupyter-client>=8.8.0 (from ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading jupyter_client-8.9.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyter-core!=6.0.*,>=5.1 (from ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading jupyter_core-5.9.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting matplotlib-inline>=0.1 (from ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading matplotlib_inline-0.2.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting nest-asyncio>=1.4 (from ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting packaging>=22 (from ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading packaging-26.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: psutil>=5.7 in /home/zhouyunqi/.clearml/venvs-builds/3.13/lib/python3.13/site-packages (from ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1)) (7.2.2)
# Collecting pyzmq>=25 (from ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading pyzmq-27.1.0-cp312-abi3-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Collecting tornado>=6.4.1 (from ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading tornado-6.5.7-cp39-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (2.8 kB)
# Collecting traitlets>=5.4.0 (from ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading traitlets-5.15.1-py3-none-any.whl.metadata (10 kB)
# Collecting decorator>=5.1.0 (from ipython>=7.23.1->ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading decorator-5.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting ipython-pygments-lexers>=1.0.0 (from ipython>=7.23.1->ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.18.2 (from ipython>=7.23.1->ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Collecting pexpect>4.6 (from ipython>=7.23.1->ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython>=7.23.1->ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading prompt_toolkit-3.0.52-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.14.0 (from ipython>=7.23.1->ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading pygments-2.20.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data>=0.6.0 (from ipython>=7.23.1->ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading wcwidth-0.8.2-py3-none-any.whl.metadata (43 kB)
# Collecting parso<0.9.0,>=0.8.6 (from jedi>=0.18.2->ipython>=7.23.1->ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading parso-0.8.7-py2.py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/zhouyunqi/.clearml/venvs-builds/3.13/lib/python3.13/site-packages (from jupyter-client>=8.8.0->ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1)) (2.9.0.post0)
# Collecting typing-extensions>=4.13.0 (from jupyter-client>=8.8.0->ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting platformdirs>=2.5 (from jupyter-core!=6.0.*,>=5.1->ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading platformdirs-4.10.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting ptyprocess>=0.5 (from pexpect>4.6->ipython>=7.23.1->ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: six>=1.5 in /home/zhouyunqi/.clearml/venvs-builds/3.13/lib/python3.13/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.8.0->ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1)) (1.17.0)
# Collecting executing>=1.2.0 (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading asttokens-3.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting pure-eval (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.2.0->-r /tmp/cached-reqsegqjfdw4.txt (line 1))
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading ipykernel-7.2.0-py3-none-any.whl (118 kB)
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading debugpy-1.8.21-cp313-cp313-manylinux_2_34_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 12.1 MB/s  0:00:00
# Downloading ipython-9.15.0-py3-none-any.whl (630 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.9/630.9 kB 33.7 MB/s  0:00:00
# Downloading prompt_toolkit-3.0.52-py3-none-any.whl (391 kB)
# Downloading decorator-5.3.1-py3-none-any.whl (10 kB)
# Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 26.9 MB/s  0:00:00
# Downloading parso-0.8.7-py2.py3-none-any.whl (107 kB)
# Downloading jupyter_client-8.9.1-py3-none-any.whl (109 kB)
# Downloading jupyter_core-5.9.1-py3-none-any.whl (29 kB)
# Downloading matplotlib_inline-0.2.2-py3-none-any.whl (9.5 kB)
# Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Downloading packaging-26.2-py3-none-any.whl (100 kB)
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Downloading platformdirs-4.10.0-py3-none-any.whl (22 kB)
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Downloading pygments-2.20.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.9 MB/s  0:00:00
# Downloading pyzmq-27.1.0-cp312-abi3-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (840 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.0/841.0 kB 24.4 MB/s  0:00:00
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-3.0.1-py3-none-any.whl (27 kB)
# Downloading executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Downloading tornado-6.5.7-cp39-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (449 kB)
# Downloading traitlets-5.15.1-py3-none-any.whl (85 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading wcwidth-0.8.2-py3-none-any.whl (323 kB)
# Installing collected packages: pure-eval, ptyprocess, wcwidth, typing-extensions, traitlets, tornado, pyzmq, pygments, platformdirs, pexpect, parso, packaging, nest-asyncio, executing, decorator, debugpy, comm, asttokens, stack_data, prompt_toolkit, matplotlib-inline, jupyter-core, jedi, ipython-pygments-lexers, jupyter-client, ipython, ipykernel
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/27 [pygments]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27/27 [ipykernel]
# Successfully installed asttokens-3.0.1 comm-0.2.3 debugpy-1.8.21 decorator-5.3.1 executing-2.2.1 ipykernel-7.2.0 ipython-9.15.0 ipython-pygments-lexers-1.1.1 jedi-0.20.0 jupyter-client-8.9.1 jupyter-core-5.9.1 matplotlib-inline-0.2.2 nest-asyncio-1.6.0 packaging-26.2 parso-0.8.7 pexpect-4.9.0 platformdirs-4.10.0 prompt_toolkit-3.0.52 ptyprocess-0.7.0 pure-eval-0.2.3 pygments-2.20.0 pyzmq-27.1.0 stack_data-0.6.3 tornado-6.5.7 traitlets-5.15.1 typing-extensions-4.15.0 wcwidth-0.8.2
# Adding venv into cache: /home/zhouyunqi/.clearml/venvs-builds/3.13
# Running task id [108aa81a4217427d84877d80d216fbe2]:
# [.]$ /home/zhouyunqi/.clearml/venvs-builds/3.13/bin/python -u ipykernel_launcher.py
# Summary - installed python packages:
# pip:
# - asttokens==3.0.1
# - attrs==26.1.0
# - certifi==2026.6.17
# - charset-normalizer==3.4.7
# - clearml==2.1.9
# - comm==0.2.3
# - debugpy==1.8.21
# - decorator==5.3.1
# - executing==2.2.1
# - furl==2.1.4
# - idna==3.18
# - ipykernel==7.2.0
# - ipython==9.15.0
# - ipython_pygments_lexers==1.1.1
# - jedi==0.20.0
# - jsonschema-specifications==2025.9.1
# - jsonschema==4.26.0
# - jupyter_client==8.9.1
# - jupyter_core==5.9.1
# - matplotlib-inline==0.2.2
# - nest-asyncio==1.6.0
# - numpy==2.4.6
# - nvidia-nccl-cu12==2.30.7
# - orderedmultidict==1.0.2
# - packaging==26.2
# - pandas==2.3.3
# - parso==0.8.7
# - pathlib2==2.3.7.post1
# - pexpect==4.9.0
# - pillow==12.2.0
# - platformdirs==4.10.0
# - prompt_toolkit==3.0.52
# - psutil==7.2.2
# - ptyprocess==0.7.0
# - pure_eval==0.2.3
# - Pygments==2.20.0
# - PyJWT==2.13.0
# - pyparsing==3.3.2
# - python-dateutil==2.9.0.post0
# - pytz==2026.2
# - PyYAML==6.0.3
# - pyzmq==27.1.0
# - referencing==0.37.0
# - requests==2.34.2
# - rpds-py==2026.6.3
# - scipy==1.18.0
# - six==1.17.0
# - stack-data==0.6.3
# - tornado==6.5.7
# - traitlets==5.15.1
# - typing_extensions==4.15.0
# - tzdata==2026.2
# - urllib3==2.7.0
# - wcwidth==0.8.2
# - xgboost==3.3.0
#
# Environment setup completed successfully
#
# Starting Task Execution:
#
# NOTE: When using the `ipython kernel` entry point, Ctrl-C will not work.
#
# To exit, you will have to explicitly quit this process, by either sending
# "quit" from a client, or using Ctrl-\ in UNIX-like environments.
#
# To read more about this, see https://github.com/ipython/ipython/issues/2049
#
#
# To connect another client to this kernel, use:
#     --existing kernel-867659.json

# %% [markdown]
# # 🥾 Next steps
#
# The agent will keep running unless manually stopped, but while it's running it is ready for tasks! So let's go to the [next notebook](https://colab.research.google.com/github/allegroai/clearml/blob/master/docs/tutorials/Getting_Started_3_Remote_Execution.ipynb) of this series and start enqueuing some tasks for this agent to work on!

# %% [markdown]
# <table>
# <tbody>
#   <tr>
#     <td>Step 1: Experiment Management</td>
#     <td><a target="_blank" href="https://colab.research.google.com/github/allegroai/clearml/blob/master/docs/tutorials/Getting_Started_1_Experiment_Management.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a></td>
#   </tr>
#   <tr>
#     <td>Step 2: Remote Agent</td>
#     <td><a target="_blank" href="https://colab.research.google.com/github/allegroai/clearml/blob/master/docs/tutorials/Getting_Started_2_Setting_Up_Agent.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a></td>
#   </tr>
#   <tr>
#     <td><b>NEXT UP -> Step 3: Remote Task Execution</b></td>
#     <td><a target="_blank" href="https://colab.research.google.com/github/allegroai/clearml/blob/master/docs/tutorials/Getting_Started_3_Remote_Execution.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a></td>
#   </tr>
# </tbody>
# </table>
